# %%
"""
combine fln.json with views in nodes.csv
    title:ID(Article), views
    A, 30293
    B, 20392
"""


import pandas as pd
import json

# %%
views_df = pd.read_csv("/Users/mark/Desktop/temp_data/20160613_views.csv", encoding='utf-8', 
                      usecols=['article', 'views'], index_col="article")

# %%
import sqlite3
conn = sqlite3.connect('example.db')

views_df.to_sql("views.db", conn)

# %%
views_df.head(10)
# Out:
#                               views
# article
# 0                              4329
# !!!                             122
# !!!EEEEE                          1
# !!!Fuck_You!!!_and_Then_Some      9
# !!!_(album)                      19
# !Dame!_!Dame!_!Dame!              3
# !HERO                             2
# !Kung                            11
# !Kung_language                   26
# !Kung_people                     16
# ERROR! Session/line number was not unique in database. History logging moved to new session 374

# %%
views_df.sample(10)
# Out:
#                                                     views
# article
# Special:WhatLinksHere/File:Maundy_Thursday_07_w...      1
# Keith_Simpson_(American_football)                       1
# Artarmon,_Sydney                                        1
# Special:WhatLinksHere/Wikipedia:Selected_annive...      1
# Talk:Coach_Barnum                                       1
# Bretaigne_Windust                                       2
# Heinlein_Prize_for_Advances_in_Space_Commercial...      5
# User_talk%3ASuryanepal                                  1
# Ckjjkc-nathani                                          1
# Special:RecentChangesLinked/Talk:Ci%C3%A1ran_Wh...      1

# %%
# need to decode url string
import urllib

urllib.unquote("User_talk%3ASuryanepal").decode('utf8')
# Out:
# u'User_talk:Suryanepal'

# %%
# turn utf string into url string
urllib.quote("User_talk:Suryanepal", safe='')
# Out:
# 'User_talk%3ASuryanepal'

# %%
fln_s_df = pd.read_csv("/Users/mark/Dropbox/Develop/Insight/knowledge_search/data/test_fln.csv", 
                       index_col=":START_ID(Article)", usecols=[":START_ID(Article)"])

# %%
fln_s_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [AccessibleComputing, Anarchism, AfghanistanHistory, AfghanistanGeography, AfghanistanPeople]

# %%
pd.concat([fln_s_df, views_df], axis=1, join_axes=[fln_s_df.index])
# Out:
#                                              Unnamed: 0 article  views
# :START_ID(Article)
# AccessibleComputing                                 NaN     NaN    NaN
# Anarchism                                           NaN     NaN    NaN
# AfghanistanHistory                                  NaN     NaN    NaN
# AfghanistanGeography                                NaN     NaN    NaN
# AfghanistanPeople                                   NaN     NaN    NaN
# AfghanistanEconomy                                  NaN     NaN    NaN
# AfghanistanCommunications                           NaN     NaN    NaN
# AfghanistanTransportations                          NaN     NaN    NaN
# AfghanistanMilitary                                 NaN     NaN    NaN
# AfghanistanTransnationalIssues                      NaN     NaN    NaN
# AssistiveTechnology                                 NaN     NaN    NaN
# AmoeboidTaxa                                        NaN     NaN    NaN
# ...

# %%
views_df.iloc[99800:998080]
# Out:
#                                        views
# article
# Agricultural_University_of_Iceland         6
# Agricultural_University_of_Norway          1
# Agricultural_University_of_Tajikistan      4
# Agricultural_University_of_Tirana          7
# Agricultural_Wheel                         5
# Agricultural_aircraft                     29
# Agricultural_and_Biological_Chemistry      1
# Agricultural_and_Forest_Meteorology        5
# Agricultural_attach%C3%A9                 11
# Agricultural_belt                          1
# Agricultural_biodiversity                 23
# Agricultural_biotechnology                29
# Agricultural_buildings                     1
# Agricultural_chemistry                    55
# Agricultural_collectivisation              1
# Agricultural_college                       2
# Agricultural_commune                       4
# Agricultural_cooperative                  99
# Agricultural_cycle                        22
# Agricultural_diversification              28
# ...

# %%
views_df.loc["Agricultural_Wheel"]
# Out:
# views    5
# Name: Agricultural_Wheel, dtype: float64

# %%
views_df.loc["Accessible_computing"]
# Out:
# views    1
# Name: Accessible_computing, dtype: float64

# %%
fln_s_df.index[:10]
# Out:
# Index([u'AccessibleComputing', u'Anarchism', u'AfghanistanHistory',
#        u'AfghanistanGeography', u'AfghanistanPeople', u'AfghanistanEconomy',
#        u'AfghanistanCommunications', u'AfghanistanTransportations',
#        u'AfghanistanMilitary', u'AfghanistanTransnationalIssues'],
#       dtype='object', name=u':START_ID(Article)')

# %% [markdown]
# # Diff Lib Fuzzy Matching

# %%
import difflib

# %%
s = "Grime daily"

# %%
views_df.index[:100].map(decode_url_string)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-77-790fa6c47043> in <module>()
# ----> 1 views_df.index[:100].map(decode_url_string)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/index.pyc in map(self, mapper)
#    2036
#    2037     def map(self, mapper):
# -> 2038         return self._arrmap(self.values, mapper)
#    2039
#    2040     def isin(self, values, level=None):
#
# pandas/src/generated.pyx in pandas.algos.arrmap_object (pandas/algos.c:81976)()
#
# <ipython-input-76-69ef90dc0695> in decode_url_string(in_string)
#       1 def decode_url_string(in_string):
# ----> 2     return urllib.unquote(in_string).decode('utf-8').replace("_", " ")
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/encodings/utf_8.pyc in decode(input, errors)
#      14
#      15 def decode(input, errors='strict'):
# ...

# %%
def decode_url_string(in_string):
    return urllib.unquote(in_string).decode('utf-8').replace("_", " ")

# %%
s.title()
# Out:
# 'Grime Daily'

# %%
df2.index.map(lambda x: difflib.get_close_matches(x, df1.index)[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-fcf95e719b3d> in <module>()
# ----> 1 df2.index.map(lambda x: difflib.get_close_matches(x, df1.index)[0])
#
# NameError: name 'df2' is not defined
